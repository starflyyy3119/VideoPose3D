# %% [markdown]
# # Environment Setup

# %%
# Check CUDA and Torch version (optional)
# !nvcc --version
import torch 
print("Torch:", torch.__version__)
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0
# Torch: 1.10.0

# %%
# Override the Pytorch and CUDA installation with specific version
# !conda install pytorch==1.10.0 torchvision==0.11.0 torchaudio==0.10.0 cudatoolkit=11.3 -c pytorch -c conda-forge -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 4.13.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /userhome/cs/mastery/anaconda3/envs/DASC7606_A2
#
#   added / updated specs:
#     - cudatoolkit=11.3
#     - pytorch==1.10.0
#     - torchaudio==0.10.0
#     - torchvision==0.11.0
#
#
# The following NEW packages will be INSTALLED:
#
#   python_abi         conda-forge/linux-64::python_abi-3.9-2_cp39
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2022.4.26-~ --> conda-forge::ca-certificates-2022.6.15-ha878542_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            pkgs/main::certifi-2022.6.15-py39h06a~ --> conda-forge::certifi-2022.6.15-py39hf3d152e_0
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# Install other necessary packages
# !pip install ffmpeg
# !pip install cdflib
# !conda update ffmpeg -y
# Out:
# Requirement already satisfied: ffmpeg in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (1.4)
# Requirement already satisfied: cdflib in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (0.4.4)
# Requirement already satisfied: attrs>=19.2.0 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from cdflib) (21.4.0)
# Requirement already satisfied: numpy in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from cdflib) (1.22.3)
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 4.13.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /userhome/cs/mastery/anaconda3/envs/DASC7606_A2
#
#   added / updated specs:
#     - ffmpeg
#
#
# The following packages will be REMOVED:
#
#   python_abi-3.9-2_cp39
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2022.6.1~ --> pkgs/main::ca-certificates-2022.4.26-h06a4308_0
#   certifi            conda-forge::certifi-2022.6.15-py39hf~ --> pkgs/main::certifi-2022.6.15-py39h06a4308_0
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# install Detectron2 
# !python -m pip install detectron2 -f \
  https://dl.fbaipublicfiles.com/detectron2/wheels/cu113/torch1.10/index.html
# Out:
# Looking in links: https://dl.fbaipublicfiles.com/detectron2/wheels/cu113/torch1.10/index.html
# Requirement already satisfied: detectron2 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (0.6+cu113)
# Requirement already satisfied: black==21.4b2 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from detectron2) (21.4b2)
# Requirement already satisfied: pydot in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from detectron2) (1.4.2)
# Requirement already satisfied: tabulate in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from detectron2) (0.8.10)
# Requirement already satisfied: fvcore<0.1.6,>=0.1.5 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from detectron2) (0.1.5.post20220512)
# Requirement already satisfied: future in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from detectron2) (0.18.2)
# Requirement already satisfied: Pillow>=7.1 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from detectron2) (9.0.1)
# Requirement already satisfied: tensorboard in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from detectron2) (2.8.0)
# Requirement already satisfied: termcolor>=1.1 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from detectron2) (1.1.0)
# Requirement already satisfied: cloudpickle in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from detectron2) (2.1.0)
# Requirement already satisfied: iopath<0.1.10,>=0.1.7 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from detectron2) (0.1.9)
# Requirement already satisfied: hydra-core>=1.1 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from detectron2) (1.2.0)
# Requirement already satisfied: tqdm>4.29.0 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from detectron2) (4.64.0)
# Requirement already satisfied: yacs>=0.1.8 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from detectron2) (0.1.8)
# Requirement already satisfied: omegaconf>=2.1 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from detectron2) (2.2.2)
# Requirement already satisfied: matplotlib in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from detectron2) (3.5.1)
# Requirement already satisfied: pycocotools>=2.0.2 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from detectron2) (2.0.4)
# Requirement already satisfied: click>=7.1.2 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from black==21.4b2->detectron2) (8.0.4)
# Requirement already satisfied: regex>=2020.1.8 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from black==21.4b2->detectron2) (2022.6.2)
# Requirement already satisfied: appdirs in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from black==21.4b2->detectron2) (1.4.4)
# Requirement already satisfied: pathspec<1,>=0.8.1 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from black==21.4b2->detectron2) (0.9.0)
# Requirement already satisfied: toml>=0.10.1 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from black==21.4b2->detectron2) (0.10.2)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from black==21.4b2->detectron2) (0.4.3)
# Requirement already satisfied: pyyaml>=5.1 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from fvcore<0.1.6,>=0.1.5->detectron2) (6.0)
# Requirement already satisfied: numpy in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from fvcore<0.1.6,>=0.1.5->detectron2) (1.22.3)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from hydra-core>=1.1->detectron2) (4.9.3)
# Requirement already satisfied: packaging in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from hydra-core>=1.1->detectron2) (21.3)
# Requirement already satisfied: portalocker in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from iopath<0.1.10,>=0.1.7->detectron2) (2.4.0)
# Requirement already satisfied: cycler>=0.10 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from matplotlib->detectron2) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from matplotlib->detectron2) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from matplotlib->detectron2) (1.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from matplotlib->detectron2) (4.31.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from matplotlib->detectron2) (3.0.7)
# Requirement already satisfied: six>=1.5 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->detectron2) (1.16.0)
# Requirement already satisfied: protobuf>=3.6.0 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from tensorboard->detectron2) (3.19.4)
# Requirement already satisfied: markdown>=2.6.8 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from tensorboard->detectron2) (3.3.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from tensorboard->detectron2) (2.6.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from tensorboard->detectron2) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from tensorboard->detectron2) (0.4.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from tensorboard->detectron2) (2.0.3)
# Requirement already satisfied: absl-py>=0.4 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from tensorboard->detectron2) (1.0.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from tensorboard->detectron2) (0.6.1)
# Requirement already satisfied: wheel>=0.26 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from tensorboard->detectron2) (0.37.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from tensorboard->detectron2) (2.27.1)
# Requirement already satisfied: grpcio>=1.24.3 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from tensorboard->detectron2) (1.44.0)
# Requirement already satisfied: setuptools>=41.0.0 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from tensorboard->detectron2) (61.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2) (5.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->detectron2) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard->detectron2) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->detectron2) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (2022.6.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (2.0.12)
# Requirement already satisfied: oauthlib>=3.0.0 in /userhome/cs/mastery/anaconda3/envs/DASC7606_A2/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->detectron2) (3.2.0)

# %% [markdown]
# ## Retreive Data

# %% [markdown]
# We have prepared the Human3.6M dataset needed:
# - [data_2d_h36m_cpn_ft_h36m_dbb.npz](https://drive.google.com/file/d/1FfnFpFzoOsJ2kzaY_L9q8buS7t2GClBL/view?usp=sharing)
# - [data_3d_h36m.npz](https://drive.google.com/file/d/1mFAlUkeIUCguSvYLib21l6VY6ByVFsQk/view?usp=sharing)

# %%
# !pip install gdown
# Out:
# WARNING: Ignoring invalid distribution -illow (/userhome/cs/am203/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/userhome/cs/am203/anaconda3/lib/python3.9/site-packages)
# Collecting gdown
#   Downloading gdown-4.5.1.tar.gz (14 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: beautifulsoup4 in /userhome/cs/am203/anaconda3/lib/python3.9/site-packages (from gdown) (4.11.1)
# Requirement already satisfied: six in /userhome/cs/am203/anaconda3/lib/python3.9/site-packages (from gdown) (1.16.0)
# Requirement already satisfied: filelock in /userhome/cs/am203/anaconda3/lib/python3.9/site-packages (from gdown) (3.6.0)
# Requirement already satisfied: tqdm in /userhome/cs/am203/anaconda3/lib/python3.9/site-packages (from gdown) (4.64.0)
# Requirement already satisfied: requests[socks] in /userhome/cs/am203/anaconda3/lib/python3.9/site-packages (from gdown) (2.28.0)
# Requirement already satisfied: soupsieve>1.2 in /userhome/cs/am203/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->gdown) (2.3.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /userhome/cs/am203/anaconda3/lib/python3.9/site-packages (from requests[socks]->gdown) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /userhome/cs/am203/anaconda3/lib/python3.9/site-packages (from requests[socks]->gdown) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /userhome/cs/am203/anaconda3/lib/python3.9/site-packages (from requests[socks]->gdown) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /userhome/cs/am203/anaconda3/lib/python3.9/site-packages (from requests[socks]->gdown) (1.26.9)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /userhome/cs/am203/anaconda3/lib/python3.9/site-packages (from requests[socks]->gdown) (1.7.1)
# Building wheels for collected packages: gdown
#   Building wheel for gdown (PEP 517) ... done
#   Created wheel for gdown: filename=gdown-4.5.1-py3-none-any.whl size=14933 sha256=63e3ba6ef7c99695d1ed27ff9ba952b8d302a0ac7f2c6abbf300d17a2ed4893e
#   Stored in directory: /userhome/cs/am203/.cache/pip/wheels/b8/79/f0/b523d25d96b0bbb12bb024b97940d08c4fcd498a00070c8d82
# Successfully built gdown
# WARNING: Ignoring invalid distribution -illow (/userhome/cs/am203/anaconda3/lib/python3.9/site-packages)
# Installing collected packages: gdown
# WARNING: Ignoring invalid distribution -illow (/userhome/cs/am203/anaconda3/lib/python3.9/site-packages)
# Successfully installed gdown-4.5.1
# WARNING: Ignoring invalid distribution -illow (/userhome/cs/am203/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/userhome/cs/am203/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/userhome/cs/am203/anaconda3/lib/python3.9/site-packages)

# %%
# download dataset from google drive
# !gdown --fuzzy https://drive.google.com/file/d/1FfnFpFzoOsJ2kzaY_L9q8buS7t2GClBL/view?usp=sharing -O data/data_2d_h36m_cpn_ft_h36m_dbb.npz
# !gdown --fuzzy https://drive.google.com/file/d/1mFAlUkeIUCguSvYLib21l6VY6ByVFsQk/view?usp=sharing -O data/data_3d_h36m.npz
# !wget -c https://dl.fbaipublicfiles.com/video-pose-3d/pretrained_h36m_cpn.bin -O checkpoint/pretrained_h36m_cpn.bin
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1FfnFpFzoOsJ2kzaY_L9q8buS7t2GClBL
# To: /userhome/cs/am203/COMP7404/VideoPose3D/data/data_2d_h36m_cpn_ft_h36m_dbb.npz
# 100%|█████████████████████████████████████████| 243M/243M [00:02<00:00, 105MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1mFAlUkeIUCguSvYLib21l6VY6ByVFsQk
# To: /userhome/cs/am203/COMP7404/VideoPose3D/data/data_3d_h36m.npz
# 100%|████████████████████████████████████████| 153M/153M [00:03<00:00, 46.8MB/s]

# %% [markdown]
# # Evaluating the pretrained model

# %%
# !python run.py -k cpn_ft_h36m_dbb -arc 3,3,3,3,3 -c checkpoint --evaluate pretrained_h36m_cpn.bin
# Out:
# Namespace(dataset='h36m', keypoints='cpn_ft_h36m_dbb', subjects_train='S1,S5,S6,S7,S8', subjects_test='S9,S11', subjects_unlabeled='', actions='*', checkpoint='checkpoint', checkpoint_frequency=10, resume='', evaluate='pretrained_h36m_cpn.bin', render=False, by_subject=False, export_training_curves=False, stride=1, epochs=60, batch_size=1024, dropout=0.25, learning_rate=0.001, lr_decay=0.95, data_augmentation=True, test_time_augmentation=True, architecture='3,3,3,3,3', causal=False, channels=1024, subset=1, downsample=1, warmup=1, no_eval=False, dense=False, disable_optimizations=False, linear_projection=False, bone_length_term=True, no_proj=False, viz_subject=None, viz_action=None, viz_camera=0, viz_video=None, viz_skip=0, viz_output=None, viz_export=None, viz_bitrate=3000, viz_no_ground_truth=False, viz_limit=-1, viz_downsample=1, viz_size=5)
# Loading dataset...
# Preparing data...
# Loading 2D detections...
# INFO: Receptive field: 243 frames
# INFO: Trainable parameter count: 16952371
# Loading checkpoint checkpoint/pretrained_h36m_cpn.bin
# This model was trained for 80 epochs
# INFO: Testing on 543344 frames
# Evaluating...
# ----Directions----
# Test time augmentation: True
# Protocol #1 Error (MPJPE): 40.8907862714504 mm
# Protocol #2 Error (P-MPJPE): 31.4224884353789 mm
# Protocol #3 Error (N-MPJPE): 37.97983393818478 mm
# Velocity Error (MPJVE): 2.2665471964834594 mm
# ----------
# ----Discussion----
# Test time augmentation: True
# Protocol #1 Error (MPJPE): 43.40995154856437 mm
# Protocol #2 Error (P-MPJPE): 33.85677452642005 mm
# Protocol #3 Error (N-MPJPE): 40.99453349549218 mm
# Velocity Error (MPJVE): 2.238868831303416 mm
# ----------
# ----Eating----
# Test time augmentation: True
# Protocol #1 Error (MPJPE): 34.79562916372048 mm
# Protocol #2 Error (P-MPJPE): 28.489283205194706 mm
# Protocol #3 Error (N-MPJPE): 34.028248713872365 mm
# Velocity Error (MPJVE): 1.6934289436455097 mm
# ----------
# ----Greeting----
# Test time augmentation: True
# Protocol #1 Error (MPJPE): 41.56884921304011 mm
# Protocol #2 Error (P-MPJPE): 33.27197086163504 mm
# Protocol #3 Error (N-MPJPE): 40.33288891690897 mm
# Velocity Error (MPJVE): 2.6246325218779076 mm
# ----------
# ----Phoning----
# Test time augmentation: True
# Protocol #1 Error (MPJPE): 43.17036431463152 mm
# Protocol #2 Error (P-MPJPE): 31.370964748119388 mm
# Protocol #3 Error (N-MPJPE): 39.91911779584889 mm
# Velocity Error (MPJVE): 1.6175419474384574 mm
# ----------
# ----Photo----
# Test time augmentation: True
# Protocol #1 Error (MPJPE): 47.63346594424174 mm
# Protocol #2 Error (P-MPJPE): 37.226915474737126 mm
# Protocol #3 Error (N-MPJPE): 44.63417698866796 mm
# Velocity Error (MPJVE): 2.0096933363163707 mm
# ----------
# ----Posing----
# Test time augmentation: True
# Protocol #1 Error (MPJPE): 43.69472625755495 mm
# Protocol #2 Error (P-MPJPE): 31.89203994631319 mm
# Protocol #3 Error (N-MPJPE): 42.126011486435615 mm
# Velocity Error (MPJVE): 2.0874952771284416 mm
# ----------
# ----Purchases----
# Test time augmentation: True
# Protocol #1 Error (MPJPE): 41.60866602614686 mm
# Protocol #2 Error (P-MPJPE): 31.16034058994233 mm
# Protocol #3 Error (N-MPJPE): 39.764263486156224 mm
# Velocity Error (MPJVE): 2.4440626590879737 mm
# ----------
# ----Sitting----
# Test time augmentation: True
# Protocol #1 Error (MPJPE): 50.29358214823876 mm
# Protocol #2 Error (P-MPJPE): 38.63063197203179 mm
# Protocol #3 Error (N-MPJPE): 48.186279752199525 mm
# Velocity Error (MPJVE): 1.2589748645229675 mm
# ----------
# ----SittingDown----
# Test time augmentation: True
# Protocol #1 Error (MPJPE): 55.92108114882222 mm
# Protocol #2 Error (P-MPJPE): 44.78226410581197 mm
# Protocol #3 Error (N-MPJPE): 53.26950835892865 mm
# Velocity Error (MPJVE): 1.756627480489525 mm
# ----------
# ----Smoking----
# Test time augmentation: True
# Protocol #1 Error (MPJPE): 43.02183963758881 mm
# Protocol #2 Error (P-MPJPE): 33.33627699196638 mm
# Protocol #3 Error (N-MPJPE): 40.375224873906404 mm
# Velocity Error (MPJVE): 1.595547384859198 mm
# ----------
# ----Waiting----
# Test time augmentation: True
# Protocol #1 Error (MPJPE): 42.51133929269053 mm
# Protocol #2 Error (P-MPJPE): 31.658620166163534 mm
# Protocol #3 Error (N-MPJPE): 40.13353799379844 mm
# Velocity Error (MPJVE): 1.8207342292318118 mm
# ----------
# ----WalkDog----
# Test time augmentation: True
# Protocol #1 Error (MPJPE): 45.02371738655856 mm
# Protocol #2 Error (P-MPJPE): 34.76586355169663 mm
# Protocol #3 Error (N-MPJPE): 41.803283132812766 mm
# Velocity Error (MPJVE): 3.063646378069645 mm
# ----------
# ----Walking----
# Test time augmentation: True
# Protocol #1 Error (MPJPE): 33.007942192167846 mm
# Protocol #2 Error (P-MPJPE): 25.8310107379834 mm
# Protocol #3 Error (N-MPJPE): 31.638811737428302 mm
# Velocity Error (MPJVE): 2.6165438115120287 mm
# ----------
# ----WalkTogether----
# Test time augmentation: True
# Protocol #1 Error (MPJPE): 32.65240135558657 mm
# Protocol #2 Error (P-MPJPE): 24.708683945653206 mm
# Protocol #3 Error (N-MPJPE): 30.528601684716204 mm
# Velocity Error (MPJVE): 2.205712452361141 mm
# ----------
# Protocol #1   (MPJPE) action-wise average: 42.6 mm
# Protocol #2 (P-MPJPE) action-wise average: 32.8 mm
# Protocol #3 (N-MPJPE) action-wise average: 40.4 mm
# Velocity      (MPJVE) action-wise average: 2.09 mm

# %% [markdown]
# # Predict arbitrary video

# %%
# Download pretrained model
# !wget -c https://dl.fbaipublicfiles.com/video-pose-3d/pretrained_h36m_detectron_coco.bin -O checkpoint/pretrained_h36m_detectron_coco.bin
# Out:
# --2022-07-09 16:48:53--  https://dl.fbaipublicfiles.com/video-pose-3d/pretrained_h36m_detectron_coco.bin
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 172.67.9.4, 104.22.75.142, 104.22.74.142, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|172.67.9.4|:443... connected.
# HTTP request sent, awaiting response... 416 Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.

# %%
# Raw files removed to save space
# !ffmpeg -i video/video1_raw.mp4 -ss 0:11 -to 0:50 -c copy video/video1.mp4
# !ffmpeg -i video/video2_raw.mp4 -ss 0:0 -to 0:50 -c copy video/video2.mp4
# !ffmpeg -i video/video3_raw.mp4 -ss 0:0 -to 0:25 -c copy video/video3.mp4
# !ffmpeg -i video/video4_raw.mp4 -ss 0:0 -to 0:25 -c copy video/video4.mp4
# Out:
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video/video4_raw.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:20.04, start: 3.040000, bitrate: 18358 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 2160x4096, 18355 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : L-SMASH Video Handler
# Output #0, mp4, to 'video/video4.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 2160x4096, q=2-31, 18355 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : L-SMASH Video Handler
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# frame=  425 fps=0.0 q=-1.0 Lsize=   38735kB time=00:00:19.92 bitrate=15929.6kbits/s speed=37.2x
# video:38730kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.013813%

# %%
# this generate npz file in inference_output, using files in 'video' as input
inference_output_dir = 'inference_output'
video_input_dir = 'video'
# !mkdir $inference_output_dir
# !cd inference; python infer_video_d2.py \
    --cfg COCO-Keypoints/keypoint_rcnn_R_101_FPN_3x.yaml \
    --output-dir ../$inference_output_dir \
    --image-ext mp4 \
    ../$video_input_dir
# Out:
# mkdir: cannot create directory ‘inference_output’: File exists
# Processing ../video/video4.mp4
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../video/video4.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:17.00, start: 3.040000, bitrate: 18665 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 2160x4096, 18663 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : L-SMASH Video Handler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, image2pipe, to 'pipe:':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: rawvideo (BGR[24] / 0x18524742), bgr24, 2160x4096, q=2-31, 5308416 kb/s, 25 fps, 25 tbn, 25 tbc (default)
#     Metadata:
#       handler_name    : L-SMASH Video Handler
#       encoder         : Lavc58.54.100 rawvideo
# /userhome/cs/am203/anaconda3/lib/python3.9/site-packages/detectron2/structures/image_list.py:88: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   max_size = (max_size + (stride - 1)) // stride * stride
# /userhome/cs/am203/anaconda3/lib/python3.9/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /opt/conda/conda-bld/pytorch_1634272204863/work/aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /userhome/cs/am203/anaconda3/lib/python3.9/site-packages/detectron2/structures/keypoints.py:224: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   y_int = (pos - x_int) // w
# Frame 0 processed in 1.008s
# Frame 1 processed in 0.168s
# Frame 2 processed in 0.194ssize=   77760kB time=00:00:00.12 bitrate=5308416.0kbits/s speed=0.0932x
# Frame 3 processed in 0.209s
# Frame 4 processed in 0.157s
# Frame 5 processed in 0.194ssize=  155520kB time=00:00:00.24 bitrate=5308416.0kbits/s speed=0.126x
# Frame 6 processed in 0.173s
# Frame 7 processed in 0.182s
# Frame 8 processed in 0.161ssize=  233280kB time=00:00:00.36 bitrate=5308416.0kbits/s speed=0.145x
# Frame 9 processed in 0.164s
# Frame 10 processed in 0.162s
# Frame 11 processed in 0.163size=  311040kB time=00:00:00.48 bitrate=5308416.0kbits/s speed=0.156x
# Frame 12 processed in 0.153s
# Frame 13 processed in 0.147s
# Frame 14 processed in 0.162size=  388800kB time=00:00:00.60 bitrate=5308416.0kbits/s speed=0.164x
# Frame 15 processed in 0.158s
# Frame 16 processed in 0.156s
# Frame 17 processed in 0.158size=  466560kB time=00:00:00.72 bitrate=5308416.0kbits/s speed=0.171x
# Frame 18 processed in 0.167s
# Frame 19 processed in 0.154s
# Frame 20 processed in 0.158size=  544320kB time=00:00:00.84 bitrate=5308416.0kbits/s speed=0.176x
# Frame 21 processed in 0.157s
# Frame 22 processed in 0.154s
# Frame 23 processed in 0.183size=  622080kB time=00:00:00.96 bitrate=5308416.0kbits/s speed=0.18x
# Frame 24 processed in 0.194s
# Frame 25 processed in 0.165s
# Frame 26 processed in 0.157size=  699840kB time=00:00:01.08 bitrate=5308416.0kbits/s speed=0.182x
# Frame 27 processed in 0.167s
# Frame 28 processed in 0.167s
# Frame 29 processed in 0.156size=  777600kB time=00:00:01.20 bitrate=5308416.0kbits/s speed=0.185x
# Frame 30 processed in 0.149s
# Frame 31 processed in 0.149s
# Frame 32 processed in 0.172size=  855360kB time=00:00:01.32 bitrate=5308416.0kbits/s speed=0.188x
# Frame 33 processed in 0.150s
# Frame 34 processed in 0.146s
# Frame 35 processed in 0.156size=  933120kB time=00:00:01.44 bitrate=5308416.0kbits/s speed=0.191x
# Frame 36 processed in 0.146s
# Frame 37 processed in 0.144s
# Frame 38 processed in 0.149s
# Frame 39 processed in 0.189size= 1036800kB time=00:00:01.60 bitrate=5308416.0kbits/s speed=0.195x
# Frame 40 processed in 0.145s
# Frame 41 processed in 0.148s
# Frame 42 processed in 0.149size= 1114560kB time=00:00:01.72 bitrate=5308416.0kbits/s speed=0.197x
# Frame 43 processed in 0.157s
# Frame 44 processed in 0.196s
# Frame 45 processed in 0.148size= 1192320kB time=00:00:01.84 bitrate=5308416.0kbits/s speed=0.199x
# Frame 46 processed in 0.147s
# Frame 47 processed in 0.164s
# Frame 48 processed in 0.172size= 1270080kB time=00:00:01.96 bitrate=5308416.0kbits/s speed= 0.2x
# Frame 49 processed in 0.200s
# Frame 50 processed in 0.156s
# Frame 51 processed in 0.153size= 1347840kB time=00:00:02.08 bitrate=5308416.0kbits/s speed= 0.2x
# Frame 52 processed in 0.159s
# Frame 53 processed in 0.150s
# Frame 54 processed in 0.194size= 1425600kB time=00:00:02.20 bitrate=5308416.0kbits/s speed=0.201x
# Frame 55 processed in 0.143s
# Frame 56 processed in 0.144s
# Frame 57 processed in 0.145size= 1503360kB time=00:00:02.32 bitrate=5308416.0kbits/s speed=0.202x
# Frame 58 processed in 0.150s
# Frame 59 processed in 0.195s
# Frame 60 processed in 0.172s
# Frame 61 processed in 0.162size= 1607040kB time=00:00:02.48 bitrate=5308416.0kbits/s speed=0.204x
# Frame 62 processed in 0.176s
# Frame 63 processed in 0.148s
# Frame 64 processed in 0.155size= 1684800kB time=00:00:02.60 bitrate=5308416.0kbits/s speed=0.204x
# Frame 65 processed in 0.154s
# Frame 66 processed in 0.147s
# Frame 67 processed in 0.167size= 1762560kB time=00:00:02.72 bitrate=5308416.0kbits/s speed=0.205x
# Frame 68 processed in 0.159s
# Frame 69 processed in 0.162s
# Frame 70 processed in 0.147size= 1840320kB time=00:00:02.84 bitrate=5308416.0kbits/s speed=0.206x
# Frame 71 processed in 0.157s
# Frame 72 processed in 0.169s
# Frame 73 processed in 0.160size= 1918080kB time=00:00:02.96 bitrate=5308416.0kbits/s speed=0.206x
# Frame 74 processed in 0.144s
# Frame 75 processed in 0.147s
# Frame 76 processed in 0.145size= 1995840kB time=00:00:03.08 bitrate=5308416.0kbits/s speed=0.207x
# Frame 77 processed in 0.150s
# Frame 78 processed in 0.145s
# Frame 79 processed in 0.184s
# Frame 80 processed in 0.153size= 2099520kB time=00:00:03.24 bitrate=5308416.0kbits/s speed=0.209x
# Frame 81 processed in 0.141s
# Frame 82 processed in 0.172s
# Frame 83 processed in 0.145size= 2177280kB time=00:00:03.36 bitrate=5308416.0kbits/s speed=0.209x
# Frame 84 processed in 0.155s
# Frame 85 processed in 0.153s
# Frame 86 processed in 0.159size= 2255040kB time=00:00:03.48 bitrate=5308416.0kbits/s speed=0.209x
# Frame 87 processed in 0.180s
# Frame 88 processed in 0.158s
# Frame 89 processed in 0.149size= 2332800kB time=00:00:03.60 bitrate=5308416.0kbits/s speed=0.209x
# Frame 90 processed in 0.161s
# Frame 91 processed in 0.158s
# Frame 92 processed in 0.179size= 2410560kB time=00:00:03.72 bitrate=5308416.0kbits/s speed=0.21x
# Frame 93 processed in 0.154s
# Frame 94 processed in 0.141s
# Frame 95 processed in 0.155size= 2488320kB time=00:00:03.84 bitrate=5308416.0kbits/s speed=0.21x
# Frame 96 processed in 0.153s
# Frame 97 processed in 0.153s
# Frame 98 processed in 0.150size= 2566080kB time=00:00:03.96 bitrate=5308416.0kbits/s speed=0.21x
# Frame 99 processed in 0.155s
# Frame 100 processed in 0.154s
# Frame 101 processed in 0.151sze= 2643840kB time=00:00:04.08 bitrate=5308416.0kbits/s speed=0.211x
# Frame 102 processed in 0.156s
# Frame 103 processed in 0.157s
# Frame 104 processed in 0.150sze= 2721600kB time=00:00:04.20 bitrate=5308416.0kbits/s speed=0.211x
# Frame 105 processed in 0.158s
# Frame 106 processed in 0.157s
# Frame 107 processed in 0.153sze= 2799360kB time=00:00:04.32 bitrate=5308416.0kbits/s speed=0.211x
# Frame 108 processed in 0.145s
# Frame 109 processed in 0.142s
# Frame 110 processed in 0.164sze= 2877120kB time=00:00:04.44 bitrate=5308416.0kbits/s speed=0.211x
# Frame 111 processed in 0.142s
# Frame 112 processed in 0.140s
# Frame 113 processed in 0.141sze= 2954880kB time=00:00:04.56 bitrate=5308416.0kbits/s speed=0.212x
# Frame 114 processed in 0.140s
# Frame 115 processed in 0.150s
# Frame 116 processed in 0.153s
# Frame 117 processed in 0.149sze= 3058560kB time=00:00:04.72 bitrate=5308416.0kbits/s speed=0.213x
# Frame 118 processed in 0.153s
# Frame 119 processed in 0.149s
# Frame 120 processed in 0.141sze= 3136320kB time=00:00:04.84 bitrate=5308416.0kbits/s speed=0.213x
# Frame 121 processed in 0.141s
# Frame 122 processed in 0.145s
# Frame 123 processed in 0.166sze= 3214080kB time=00:00:04.96 bitrate=5308416.0kbits/s speed=0.214x
# Frame 124 processed in 0.143s
# Frame 125 processed in 0.142s
# Frame 126 processed in 0.169sze= 3291840kB time=00:00:05.08 bitrate=5308416.0kbits/s speed=0.214x
# Frame 127 processed in 0.162s
# Frame 128 processed in 0.171s
# Frame 129 processed in 0.154sze= 3369600kB time=00:00:05.20 bitrate=5308416.0kbits/s speed=0.214x
# Frame 130 processed in 0.151s
# Frame 131 processed in 0.171s
# Frame 132 processed in 0.157sze= 3447360kB time=00:00:05.32 bitrate=5308416.0kbits/s speed=0.214x
# Frame 133 processed in 0.172s
# Frame 134 processed in 0.158s
# Frame 135 processed in 0.159sze= 3525120kB time=00:00:05.44 bitrate=5308416.0kbits/s speed=0.214x
# Frame 136 processed in 0.145s
# Frame 137 processed in 0.155s
# Frame 138 processed in 0.161sze= 3602880kB time=00:00:05.56 bitrate=5308416.0kbits/s speed=0.214x
# Frame 139 processed in 0.162s
# Frame 140 processed in 0.160s
# Frame 141 processed in 0.156sze= 3680640kB time=00:00:05.68 bitrate=5308416.0kbits/s speed=0.214x
# Frame 142 processed in 0.163s
# Frame 143 processed in 0.159s
# Frame 144 processed in 0.155sze= 3758400kB time=00:00:05.80 bitrate=5308416.0kbits/s speed=0.214x
# Frame 145 processed in 0.162s
# Frame 146 processed in 0.164s
# Frame 147 processed in 0.157sze= 3836160kB time=00:00:05.92 bitrate=5308416.0kbits/s speed=0.214x
# Frame 148 processed in 0.164s
# Frame 149 processed in 0.162s
# Frame 150 processed in 0.167sze= 3913920kB time=00:00:06.04 bitrate=5308416.0kbits/s speed=0.214x
# Frame 151 processed in 0.166s
# Frame 152 processed in 0.163s
# Frame 153 processed in 0.164sze= 3991680kB time=00:00:06.16 bitrate=5308416.0kbits/s speed=0.214x
# Frame 154 processed in 0.165s
# Frame 155 processed in 0.158s
# Frame 156 processed in 0.163sze= 4069440kB time=00:00:06.28 bitrate=5308416.0kbits/s speed=0.214x
# Frame 157 processed in 0.164s
# Frame 158 processed in 0.162s
# Frame 159 processed in 0.162sze= 4147200kB time=00:00:06.40 bitrate=5308416.0kbits/s speed=0.213x
# Frame 160 processed in 0.156s
# Frame 161 processed in 0.164s
# Frame 162 processed in 0.169sze= 4224960kB time=00:00:06.52 bitrate=5308416.0kbits/s speed=0.213x
# Frame 163 processed in 0.163s
# Frame 164 processed in 0.163s
# Frame 165 processed in 0.161sze= 4302720kB time=00:00:06.64 bitrate=5308416.0kbits/s speed=0.213x
# Frame 166 processed in 0.162s
# Frame 167 processed in 0.161s
# Frame 168 processed in 0.156sze= 4380480kB time=00:00:06.76 bitrate=5308416.0kbits/s speed=0.213x
# Frame 169 processed in 0.155s
# Frame 170 processed in 0.162s
# Frame 171 processed in 0.158sze= 4458240kB time=00:00:06.88 bitrate=5308416.0kbits/s speed=0.213x
# Frame 172 processed in 0.158s
# Frame 173 processed in 0.162s
# Frame 174 processed in 0.155sze= 4536000kB time=00:00:07.00 bitrate=5308416.0kbits/s speed=0.213x
# Frame 175 processed in 0.160s
# Frame 176 processed in 0.150s
# Frame 177 processed in 0.160sze= 4613760kB time=00:00:07.12 bitrate=5308416.0kbits/s speed=0.213x
# Frame 178 processed in 0.147s
# Frame 179 processed in 0.142s
# Frame 180 processed in 0.141sze= 4691520kB time=00:00:07.24 bitrate=5308416.0kbits/s speed=0.213x
# Frame 181 processed in 0.140s
# Frame 182 processed in 0.144s
# Frame 183 processed in 0.145s
# Frame 184 processed in 0.142sze= 4795200kB time=00:00:07.40 bitrate=5308416.0kbits/s speed=0.214x
# Frame 185 processed in 0.144s
# Frame 186 processed in 0.144s
# Frame 187 processed in 0.143s
# Frame 188 processed in 0.142sze= 4898880kB time=00:00:07.56 bitrate=5308416.0kbits/s speed=0.215x
# Frame 189 processed in 0.162s
# Frame 190 processed in 0.148s
# Frame 191 processed in 0.151sze= 4976640kB time=00:00:07.68 bitrate=5308416.0kbits/s speed=0.215x
# Frame 192 processed in 0.149s
# Frame 193 processed in 0.149s
# Frame 194 processed in 0.139sze= 5054400kB time=00:00:07.80 bitrate=5308416.0kbits/s speed=0.215x
# Frame 195 processed in 0.138s
# Frame 196 processed in 0.139s
# Frame 197 processed in 0.143sze= 5132160kB time=00:00:07.92 bitrate=5308416.0kbits/s speed=0.216x
# Frame 198 processed in 0.145s
# Frame 199 processed in 0.145s
# Frame 200 processed in 0.143s
# Frame 201 processed in 0.143sze= 5235840kB time=00:00:08.08 bitrate=5308416.0kbits/s speed=0.216x
# Frame 202 processed in 0.146s
# Frame 203 processed in 0.145s
# Frame 204 processed in 0.140s
# Frame 205 processed in 0.142sze= 5339520kB time=00:00:08.24 bitrate=5308416.0kbits/s speed=0.217x
# Frame 206 processed in 0.146s
# Frame 207 processed in 0.154s
# Frame 208 processed in 0.154s
# Frame 209 processed in 0.150sze= 5443200kB time=00:00:08.40 bitrate=5308416.0kbits/s speed=0.217x
# Frame 210 processed in 0.149s
# Frame 211 processed in 0.157s
# Frame 212 processed in 0.143sze= 5520960kB time=00:00:08.52 bitrate=5308416.0kbits/s speed=0.217x
# Frame 213 processed in 0.146s
# Frame 214 processed in 0.162s
# Frame 215 processed in 0.143sze= 5598720kB time=00:00:08.64 bitrate=5308416.0kbits/s speed=0.217x
# Frame 216 processed in 0.143s
# Frame 217 processed in 0.142s
# Frame 218 processed in 0.143s
# Frame 219 processed in 0.159sze= 5702400kB time=00:00:08.80 bitrate=5308416.0kbits/s speed=0.218x
# Frame 220 processed in 0.144s
# Frame 221 processed in 0.138s
# Frame 222 processed in 0.138s
# Frame 223 processed in 0.146sze= 5806080kB time=00:00:08.96 bitrate=5308416.0kbits/s speed=0.218x
# Frame 224 processed in 0.153s
# Frame 225 processed in 0.144s
# Frame 226 processed in 0.151sze= 5883840kB time=00:00:09.08 bitrate=5308416.0kbits/s speed=0.219x
# Frame 227 processed in 0.148s
# Frame 228 processed in 0.148s
# Frame 229 processed in 0.156sze= 5961600kB time=00:00:09.20 bitrate=5308416.0kbits/s speed=0.219x
# Frame 230 processed in 0.149s
# Frame 231 processed in 0.143s
# Frame 232 processed in 0.157sze= 6039360kB time=00:00:09.32 bitrate=5308416.0kbits/s speed=0.219x
# Frame 233 processed in 0.145s
# Frame 234 processed in 0.141s
# Frame 235 processed in 0.178sze= 6117120kB time=00:00:09.44 bitrate=5308416.0kbits/s speed=0.219x
# Frame 236 processed in 0.181s
# Frame 237 processed in 0.140s
# Frame 238 processed in 0.153sze= 6194880kB time=00:00:09.56 bitrate=5308416.0kbits/s speed=0.219x
# Frame 239 processed in 0.146s
# Frame 240 processed in 0.166s
# Frame 241 processed in 0.162sze= 6272640kB time=00:00:09.68 bitrate=5308416.0kbits/s speed=0.219x
# Frame 242 processed in 0.145s
# Frame 243 processed in 0.155s
# Frame 244 processed in 0.145sze= 6350400kB time=00:00:09.80 bitrate=5308416.0kbits/s speed=0.219x
# Frame 245 processed in 0.165s
# Frame 246 processed in 0.157s
# Frame 247 processed in 0.146sze= 6428160kB time=00:00:09.92 bitrate=5308416.0kbits/s speed=0.219x
# Frame 248 processed in 0.155s
# Frame 249 processed in 0.158s
# Frame 250 processed in 0.149sze= 6505920kB time=00:00:10.04 bitrate=5308416.0kbits/s speed=0.219x
# Frame 251 processed in 0.156s
# Frame 252 processed in 0.154s
# Frame 253 processed in 0.152sze= 6583680kB time=00:00:10.16 bitrate=5308416.0kbits/s speed=0.219x
# Frame 254 processed in 0.155s
# Frame 255 processed in 0.153s
# Frame 256 processed in 0.155sze= 6661440kB time=00:00:10.28 bitrate=5308416.0kbits/s speed=0.219x
# Frame 257 processed in 0.161s
# Frame 258 processed in 0.162s
# Frame 259 processed in 0.159sze= 6739200kB time=00:00:10.40 bitrate=5308416.0kbits/s speed=0.219x
# Frame 260 processed in 0.161s
# Frame 261 processed in 0.159s
# Frame 262 processed in 0.165sze= 6816960kB time=00:00:10.52 bitrate=5308416.0kbits/s speed=0.219x
# Frame 263 processed in 0.163s
# Frame 264 processed in 0.160s
# Frame 265 processed in 0.162sze= 6894720kB time=00:00:10.64 bitrate=5308416.0kbits/s speed=0.219x
# Frame 266 processed in 0.165s
# Frame 267 processed in 0.162s
# Frame 268 processed in 0.163sze= 6972480kB time=00:00:10.76 bitrate=5308416.0kbits/s speed=0.219x
# Frame 269 processed in 0.190s
# Frame 270 processed in 0.194s
# Frame 271 processed in 0.187sze= 7050240kB time=00:00:10.88 bitrate=5308416.0kbits/s speed=0.218x
# Frame 272 processed in 0.171s
# Frame 273 processed in 0.186s
# Frame 274 processed in 0.154sze= 7128000kB time=00:00:11.00 bitrate=5308416.0kbits/s speed=0.218x
# Frame 275 processed in 0.155s
# Frame 276 processed in 0.158s
# Frame 277 processed in 0.156sze= 7205760kB time=00:00:11.12 bitrate=5308416.0kbits/s speed=0.218x
# Frame 278 processed in 0.158s
# Frame 279 processed in 0.151s
# Frame 280 processed in 0.148sze= 7283520kB time=00:00:11.24 bitrate=5308416.0kbits/s speed=0.218x
# Frame 281 processed in 0.170s
# Frame 282 processed in 0.155s
# Frame 283 processed in 0.154sze= 7361280kB time=00:00:11.36 bitrate=5308416.0kbits/s speed=0.218x
# Frame 284 processed in 0.157s
# Frame 285 processed in 0.156s
# Frame 286 processed in 0.153sze= 7439040kB time=00:00:11.48 bitrate=5308416.0kbits/s speed=0.218x
# Frame 287 processed in 0.155s
# Frame 288 processed in 0.149s
# Frame 289 processed in 0.154sze= 7516800kB time=00:00:11.60 bitrate=5308416.0kbits/s speed=0.218x
# Frame 290 processed in 0.151s
# Frame 291 processed in 0.152s
# Frame 292 processed in 0.155sze= 7594560kB time=00:00:11.72 bitrate=5308416.0kbits/s speed=0.218x
# Frame 293 processed in 0.153s
# Frame 294 processed in 0.155s
# Frame 295 processed in 0.160sze= 7672320kB time=00:00:11.84 bitrate=5308416.0kbits/s speed=0.218x
# Frame 296 processed in 0.160s
# Frame 297 processed in 0.159s
# Frame 298 processed in 0.156sze= 7750080kB time=00:00:11.96 bitrate=5308416.0kbits/s speed=0.218x
# Frame 299 processed in 0.166s
# Frame 300 processed in 0.164s
# Frame 301 processed in 0.170sze= 7827840kB time=00:00:12.08 bitrate=5308416.0kbits/s speed=0.218x
# Frame 302 processed in 0.152s
# Frame 303 processed in 0.152s
# Frame 304 processed in 0.157sze= 7905600kB time=00:00:12.20 bitrate=5308416.0kbits/s speed=0.218x
# Frame 305 processed in 0.154s
# Frame 306 processed in 0.178s
# Frame 307 processed in 0.176sze= 7983360kB time=00:00:12.32 bitrate=5308416.0kbits/s speed=0.218x
# Frame 308 processed in 0.154s
# Frame 309 processed in 0.148s
# Frame 310 processed in 0.154sze= 8061120kB time=00:00:12.44 bitrate=5308416.0kbits/s speed=0.218x
# Frame 311 processed in 0.187s
# Frame 312 processed in 0.171s
# Frame 313 processed in 0.150sze= 8138880kB time=00:00:12.56 bitrate=5308416.0kbits/s speed=0.218x
# Frame 314 processed in 0.155s
# Frame 315 processed in 0.172s
# Frame 316 processed in 0.206sze= 8216640kB time=00:00:12.68 bitrate=5308416.0kbits/s speed=0.218x
# Frame 317 processed in 0.200s
# Frame 318 processed in 0.154s
# Frame 319 processed in 0.161sze= 8294400kB time=00:00:12.80 bitrate=5308416.0kbits/s speed=0.217x
# Frame 320 processed in 0.157s
# Frame 321 processed in 0.194s
# Frame 322 processed in 0.200sze= 8372160kB time=00:00:12.92 bitrate=5308416.0kbits/s speed=0.217x
# Frame 323 processed in 0.154s
# Frame 324 processed in 0.181s
# Frame 325 processed in 0.162sze= 8449920kB time=00:00:13.04 bitrate=5308416.0kbits/s speed=0.217x
# Frame 326 processed in 0.191s
# Frame 327 processed in 0.175s
# Frame 328 processed in 0.158sze= 8527680kB time=00:00:13.16 bitrate=5308416.0kbits/s speed=0.217x
# Frame 329 processed in 0.157s
# Frame 330 processed in 0.168s
# Frame 331 processed in 0.165sze= 8605440kB time=00:00:13.28 bitrate=5308416.0kbits/s speed=0.217x
# Frame 332 processed in 0.183s
# Frame 333 processed in 0.160s
# Frame 334 processed in 0.162sze= 8683200kB time=00:00:13.40 bitrate=5308416.0kbits/s speed=0.217x
# Frame 335 processed in 0.159s
# Frame 336 processed in 0.150s
# Frame 337 processed in 0.186sze= 8760960kB time=00:00:13.52 bitrate=5308416.0kbits/s speed=0.217x
# Frame 338 processed in 0.149s
# Frame 339 processed in 0.144s
# Frame 340 processed in 0.142sze= 8838720kB time=00:00:13.64 bitrate=5308416.0kbits/s speed=0.217x
# Frame 341 processed in 0.144s
# Frame 342 processed in 0.186s
# Frame 343 processed in 0.144s
# Frame 344 processed in 0.144sze= 8942400kB time=00:00:13.80 bitrate=5308416.0kbits/s speed=0.217x
# Frame 345 processed in 0.147s
# Frame 346 processed in 0.143s
# Frame 347 processed in 0.189s
# Frame 348 processed in 0.144sze= 9046080kB time=00:00:13.96 bitrate=5308416.0kbits/s speed=0.217x
# Frame 349 processed in 0.144s
# Frame 350 processed in 0.140s
# Frame 351 processed in 0.142sze= 9123840kB time=00:00:14.08 bitrate=5308416.0kbits/s speed=0.217x
# Frame 352 processed in 0.180s
# Frame 353 processed in 0.139s
# Frame 354 processed in 0.143sze= 9201600kB time=00:00:14.20 bitrate=5308416.0kbits/s speed=0.217x
# Frame 355 processed in 0.151s
# Frame 356 processed in 0.148s
# Frame 357 processed in 0.186s
# Frame 358 processed in 0.143sze= 9305280kB time=00:00:14.36 bitrate=5308416.0kbits/s speed=0.218x
# Frame 359 processed in 0.143s
# Frame 360 processed in 0.143s
# Frame 361 processed in 0.142sze= 9383040kB time=00:00:14.48 bitrate=5308416.0kbits/s speed=0.218x
# Frame 362 processed in 0.184s
# Frame 363 processed in 0.164s
# Frame 364 processed in 0.144sze= 9460800kB time=00:00:14.60 bitrate=5308416.0kbits/s speed=0.218x
# Frame 365 processed in 0.143s
# Frame 366 processed in 0.152s
# Frame 367 processed in 0.140s
# Frame 368 processed in 0.143sze= 9564480kB time=00:00:14.76 bitrate=5308416.0kbits/s speed=0.218x
# Frame 369 processed in 0.151s
# Frame 370 processed in 0.153s
# Frame 371 processed in 0.151sze= 9642240kB time=00:00:14.88 bitrate=5308416.0kbits/s speed=0.218x
# Frame 372 processed in 0.152s
# Frame 373 processed in 0.174s
# Frame 374 processed in 0.209sze= 9720000kB time=00:00:15.00 bitrate=5308416.0kbits/s speed=0.218x
# Frame 375 processed in 0.154s
# Frame 376 processed in 0.175s
# Frame 377 processed in 0.148sze= 9797760kB time=00:00:15.12 bitrate=5308416.0kbits/s speed=0.218x
# Frame 378 processed in 0.161s
# Frame 379 processed in 0.157s
# Frame 380 processed in 0.165sze= 9875520kB time=00:00:15.24 bitrate=5308416.0kbits/s speed=0.218x
# Frame 381 processed in 0.185s
# Frame 382 processed in 0.162s
# Frame 383 processed in 0.159sze= 9953280kB time=00:00:15.36 bitrate=5308416.0kbits/s speed=0.218x
# Frame 384 processed in 0.151s
# Frame 385 processed in 0.156s
# Frame 386 processed in 0.189sze=10031040kB time=00:00:15.48 bitrate=5308416.0kbits/s speed=0.218x
# Frame 387 processed in 0.145s
# Frame 388 processed in 0.143s
# Frame 389 processed in 0.149sze=10108800kB time=00:00:15.60 bitrate=5308416.0kbits/s speed=0.218x
# Frame 390 processed in 0.159s
# Frame 391 processed in 0.199s
# Frame 392 processed in 0.147sze=10186560kB time=00:00:15.72 bitrate=5308416.0kbits/s speed=0.218x
# Frame 393 processed in 0.144s
# Frame 394 processed in 0.143s
# Frame 395 processed in 0.167sze=10264320kB time=00:00:15.84 bitrate=5308416.0kbits/s speed=0.218x
# Frame 396 processed in 0.170s
# Frame 397 processed in 0.152s
# Frame 398 processed in 0.158sze=10342080kB time=00:00:15.96 bitrate=5308416.0kbits/s speed=0.218x
# Frame 399 processed in 0.159s
# Frame 400 processed in 0.152s
# Frame 401 processed in 0.162sze=10419840kB time=00:00:16.08 bitrate=5308416.0kbits/s speed=0.218x
# Frame 402 processed in 0.152s
# Frame 403 processed in 0.147s
# Frame 404 processed in 0.156sze=10497600kB time=00:00:16.20 bitrate=5308416.0kbits/s speed=0.218x
# Frame 405 processed in 0.142s
# Frame 406 processed in 0.188s
# Frame 407 processed in 0.183sze=10575360kB time=00:00:16.32 bitrate=5308416.0kbits/s speed=0.218x
# Frame 408 processed in 0.140s
# Frame 409 processed in 0.143s
# Frame 410 processed in 0.156sze=10653120kB time=00:00:16.44 bitrate=5308416.0kbits/s speed=0.218x
# Frame 411 processed in 0.171s
# Frame 412 processed in 0.174s
# Frame 413 processed in 0.156sze=10730880kB time=00:00:16.56 bitrate=5308416.0kbits/s speed=0.218x
# Frame 414 processed in 0.154s
# Frame 415 processed in 0.151s
# Frame 416 processed in 0.149sze=10808640kB time=00:00:16.68 bitrate=5308416.0kbits/s speed=0.218x
# Frame 417 processed in 0.151s
# Frame 418 processed in 0.155s
# Frame 419 processed in 0.156sze=10886400kB time=00:00:16.80 bitrate=5308416.0kbits/s speed=0.218x
# Frame 420 processed in 0.150s
# Frame 421 processed in 0.151s
# Frame 422 processed in 0.148sze=10964160kB time=00:00:16.92 bitrate=5308416.0kbits/s speed=0.218x
# frame=  424 fps=5.4 q=-0.0 Lsize=10990080kB time=00:00:16.96 bitrate=5308416.0kbits/s speed=0.217x
# video:10990080kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# Frame 423 processed in 0.156s
# /userhome/cs/am203/anaconda3/lib/python3.9/site-packages/numpy/lib/npyio.py:719: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   val = np.asanyarray(val)

# %%
# Create custom dataset
# will result in data/data_2d_custom_video.npz
video_num = 4
for i in range(video_num):
    input_video = 'video' + str(i+1)
    # !cd data; python prepare_data_2d_custom.py -i ../$inference_output_dir -o $input_video
# !ls -alt data
# Out:
# Parsing 2D detections from ../inference_output
# Processing ../inference_output/video4.mp4.npz
# 424 total frames processed
# 0 frames were interpolated
# ----------
# Processing ../inference_output/video1.mp4.npz
# 1022 total frames processed
# 0 frames were interpolated
# ----------
# Processing ../inference_output/video3.mp4.npz
# 719 total frames processed
# 0 frames were interpolated
# ----------
# Processing ../inference_output/video2.mp4.npz
# 195 total frames processed
# 0 frames were interpolated
# ----------
# Saving...
# Done.
# Parsing 2D detections from ../inference_output
# Processing ../inference_output/video4.mp4.npz
# 424 total frames processed
# 0 frames were interpolated
# ----------
# Processing ../inference_output/video1.mp4.npz
# 1022 total frames processed
# 0 frames were interpolated
# ----------
# Processing ../inference_output/video3.mp4.npz
# 719 total frames processed
# 0 frames were interpolated
# ----------
# Processing ../inference_output/video2.mp4.npz
# 195 total frames processed
# 0 frames were interpolated
# ----------
# Saving...
# Done.
# Parsing 2D detections from ../inference_output
# Processing ../inference_output/video4.mp4.npz
# 424 total frames processed
# 0 frames were interpolated
# ----------
# Processing ../inference_output/video1.mp4.npz
# 1022 total frames processed
# 0 frames were interpolated
# ----------
# Processing ../inference_output/video3.mp4.npz
# 719 total frames processed
# 0 frames were interpolated
# ----------
# Processing ../inference_output/video2.mp4.npz
# 195 total frames processed
# 0 frames were interpolated
# ----------
# Saving...
# Done.
# Parsing 2D detections from ../inference_output
# Processing ../inference_output/video4.mp4.npz
# 424 total frames processed
# 0 frames were interpolated
# ----------
# Processing ../inference_output/video1.mp4.npz
# 1022 total frames processed
# 0 frames were interpolated
# ----------
# Processing ../inference_output/video3.mp4.npz
# 719 total frames processed
# 0 frames were interpolated
# ----------
# Processing ../inference_output/video2.mp4.npz
# 195 total frames processed
# 0 frames were interpolated
# ----------
# Saving...
# Done.
# total 388218
# -rw-rw-r--  1 am203 am203    275506 Jul 13 01:03 data_2d_custom_video4.npz
# drwxrwxr-x  4 am203 am203        19 Jul 13 01:03 .
# -rw-rw-r--  1 am203 am203    275506 Jul 13 01:03 data_2d_custom_video3.npz
# -rw-rw-r--  1 am203 am203    275506 Jul 13 01:03 data_2d_custom_video2.npz
# -rw-rw-r--  1 am203 am203    275506 Jul 13 01:03 data_2d_custom_video1.npz
# drwxrwxr-x 13 am203 am203        23 Jul 13 01:03 ..
# -rw-rw-r--  1 am203 am203    275506 Jul 13 00:59 data_2d_custom_video.npz
# -rw-rw-r--  1 am203 am203 153173634 Jul 12 10:43 data_3d_h36m.npz
# -rw-rw-r--  1 am203 am203 242734798 Jul 12 10:43 data_2d_h36m_cpn_ft_h36m_dbb.npz
# drwxrwxr-x  2 am203 am203         2 Jul  4 23:41 .ipynb_checkpoints
# drwxrwxr-x  2 am203 am203         3 Jul  4 23:39 __pycache__
# -rw-rw-r--  1 am203 am203      7285 Jul  4 22:09 prepare_data_h36m.py
# -rw-rw-r--  1 am203 am203      9530 Jul  4 22:09 prepare_data_humaneva.py
# -rw-rw-r--  1 am203 am203      3447 Jul  4 22:09 prepare_data_2d_custom.py
# -rw-rw-r--  1 am203 am203      2820 Jul  4 22:09 prepare_data_2d_h36m_generic.py
# -rw-rw-r--  1 am203 am203      3717 Jul  4 22:09 prepare_data_2d_h36m_sh.py
# -rw-rw-r--  1 am203 am203       597 Jul  4 22:09 convert_cdf_to_mat.m
# -rw-rw-r--  1 am203 am203      2719 Jul  4 22:09 data_utils.py
# -rw-rw-r--  1 am203 am203      6983 Jul  4 22:09 ConvertHumanEva.m

# %%
output_dir = 'video_output'
video_input_dir = 'video'
for i in range(video_num):
    input_video = 'video' + str(i+1)
    input_video_filename = input_video + '.mp4'
    output_video_filename = 'output_video' + str(i+1) + '.mp4'
    # !python run.py \
    -d custom \
    -k {input_video} \
    -arc 3,3,3,3,3 \
    -c checkpoint \
    --evaluate pretrained_h36m_detectron_coco.bin \
    --render \
    --viz-subject {input_video_filename} \
    --viz-action custom \
    --viz-video {video_input_dir + "/" + input_video_filename} \
    --viz-output {output_dir + "/" + output_video_filename} \
    --viz-size 6
# Out:
# Namespace(dataset='custom', keypoints='video1', subjects_train='S1,S5,S6,S7,S8', subjects_test='S9,S11', subjects_unlabeled='', actions='*', checkpoint='checkpoint', checkpoint_frequency=10, resume='', evaluate='pretrained_h36m_detectron_coco.bin', render=True, by_subject=False, export_training_curves=False, stride=1, epochs=60, batch_size=1024, dropout=0.25, learning_rate=0.001, lr_decay=0.95, data_augmentation=True, test_time_augmentation=True, architecture='3,3,3,3,3', causal=False, channels=1024, subset=1, downsample=1, warmup=1, no_eval=False, dense=False, disable_optimizations=False, linear_projection=False, bone_length_term=True, no_proj=False, viz_subject='video1.mp4', viz_action='custom', viz_camera=0, viz_video='video/video1.mp4', viz_skip=0, viz_output='video_output/output_video1.mp4', viz_export=None, viz_bitrate=3000, viz_no_ground_truth=False, viz_limit=-1, viz_downsample=1, viz_size=6)
# Loading dataset...
# Preparing data...
# Loading 2D detections...
# INFO: Receptive field: 243 frames
# INFO: Trainable parameter count: 16952371
# Loading checkpoint checkpoint/pretrained_h36m_detectron_coco.bin
# This model was trained for 80 epochs
# INFO: Testing on 1022 frames
# Rendering...
# INFO: this action is unlabeled. Ground truth will not be rendered.
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video/video1.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf56.4.101
#     description     : Packed by Bilibili XCoder v2.0.2
#   Duration: 00:00:38.00, start: 0.015000, bitrate: 1780 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], 1868 kb/s, 30 fps, 30 tbr, 16k tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 95 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, image2pipe, to 'pipe:':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     description     : Packed by Bilibili XCoder v2.0.2
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: rawvideo (RGB[24] / 0x18424752), rgb24, 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 663552 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 rawvideo
# frame= 1022 fps=134 q=-0.0 Lsize= 2759400kB time=00:00:38.06 bitrate=593826.7kbits/s speed=4.97x
# video:2759400kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# /userhome/cs/am203/COMP7404/VideoPose3D/common/visualization.py:198: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   fig.tight_layout()
# Namespace(dataset='custom', keypoints='video2', subjects_train='S1,S5,S6,S7,S8', subjects_test='S9,S11', subjects_unlabeled='', actions='*', checkpoint='checkpoint', checkpoint_frequency=10, resume='', evaluate='pretrained_h36m_detectron_coco.bin', render=True, by_subject=False, export_training_curves=False, stride=1, epochs=60, batch_size=1024, dropout=0.25, learning_rate=0.001, lr_decay=0.95, data_augmentation=True, test_time_augmentation=True, architecture='3,3,3,3,3', causal=False, channels=1024, subset=1, downsample=1, warmup=1, no_eval=False, dense=False, disable_optimizations=False, linear_projection=False, bone_length_term=True, no_proj=False, viz_subject='video2.mp4', viz_action='custom', viz_camera=0, viz_video='video/video2.mp4', viz_skip=0, viz_output='video_output/output_video2.mp4', viz_export=None, viz_bitrate=3000, viz_no_ground_truth=False, viz_limit=-1, viz_downsample=1, viz_size=6)
# Loading dataset...
# Preparing data...
# Loading 2D detections...
# INFO: Receptive field: 243 frames
# INFO: Trainable parameter count: 16952371
# Loading checkpoint checkpoint/pretrained_h36m_detectron_coco.bin
# This model was trained for 80 epochs
# INFO: Testing on 195 frames
# Rendering...
# INFO: this action is unlabeled. Ground truth will not be rendered.
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video/video2.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41isomavc1
#     creation_time   : 2020-09-18T13:23:23.000000Z
#   Duration: 00:00:07.81, start: 0.000000, bitrate: 5132 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080, 4878 kb/s, 25 fps, 25 tbr, 25 tbn, 50 tbc (default)
#     Metadata:
#       creation_time   : 2020-09-18T13:23:23.000000Z
#       handler_name    : L-SMASH Video Handler
#       encoder         : AVC Coding
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 253 kb/s (default)
#     Metadata:
#       creation_time   : 2020-09-18T13:23:23.000000Z
#       handler_name    : L-SMASH Audio Handler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, image2pipe, to 'pipe:':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41isomavc1
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: rawvideo (RGB[24] / 0x18424752), rgb24, 1920x1080, q=2-31, 1244160 kb/s, 25 fps, 25 tbn, 25 tbc (default)
#     Metadata:
#       creation_time   : 2020-09-18T13:23:23.000000Z
#       handler_name    : L-SMASH Video Handler
#       encoder         : Lavc58.54.100 rawvideo
# frame=  195 fps= 64 q=-0.0 Lsize= 1184625kB time=00:00:07.80 bitrate=1244160.0kbits/s speed=2.57x
# video:1184625kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# /userhome/cs/am203/COMP7404/VideoPose3D/common/visualization.py:198: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   fig.tight_layout()
# Namespace(dataset='custom', keypoints='video3', subjects_train='S1,S5,S6,S7,S8', subjects_test='S9,S11', subjects_unlabeled='', actions='*', checkpoint='checkpoint', checkpoint_frequency=10, resume='', evaluate='pretrained_h36m_detectron_coco.bin', render=True, by_subject=False, export_training_curves=False, stride=1, epochs=60, batch_size=1024, dropout=0.25, learning_rate=0.001, lr_decay=0.95, data_augmentation=True, test_time_augmentation=True, architecture='3,3,3,3,3', causal=False, channels=1024, subset=1, downsample=1, warmup=1, no_eval=False, dense=False, disable_optimizations=False, linear_projection=False, bone_length_term=True, no_proj=False, viz_subject='video3.mp4', viz_action='custom', viz_camera=0, viz_video='video/video3.mp4', viz_skip=0, viz_output='video_output/output_video3.mp4', viz_export=None, viz_bitrate=3000, viz_no_ground_truth=False, viz_limit=-1, viz_downsample=1, viz_size=6)
# Loading dataset...
# Preparing data...
# Loading 2D detections...
# INFO: Receptive field: 243 frames
# INFO: Trainable parameter count: 16952371
# Loading checkpoint checkpoint/pretrained_h36m_detectron_coco.bin
# This model was trained for 80 epochs
# INFO: Testing on 719 frames
# Rendering...
# INFO: this action is unlabeled. Ground truth will not be rendered.
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video/video3.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:25.00, start: 0.000000, bitrate: 2777 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720, 2745 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : L-SMASH Video Handler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 137 kb/s (default)
#     Metadata:
#       handler_name    : L-SMASH Audio Handler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, image2pipe, to 'pipe:':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: rawvideo (RGB[24] / 0x18424752), rgb24, 1280x720, q=2-31, 663552 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : L-SMASH Video Handler
#       encoder         : Lavc58.54.100 rawvideo
# frame=  719 fps=123 q=-0.0 Lsize= 1941300kB time=00:00:25.10 bitrate=633590.8kbits/s speed= 4.3x
# video:1941300kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# /userhome/cs/am203/COMP7404/VideoPose3D/common/visualization.py:198: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   fig.tight_layout()
# Namespace(dataset='custom', keypoints='video4', subjects_train='S1,S5,S6,S7,S8', subjects_test='S9,S11', subjects_unlabeled='', actions='*', checkpoint='checkpoint', checkpoint_frequency=10, resume='', evaluate='pretrained_h36m_detectron_coco.bin', render=True, by_subject=False, export_training_curves=False, stride=1, epochs=60, batch_size=1024, dropout=0.25, learning_rate=0.001, lr_decay=0.95, data_augmentation=True, test_time_augmentation=True, architecture='3,3,3,3,3', causal=False, channels=1024, subset=1, downsample=1, warmup=1, no_eval=False, dense=False, disable_optimizations=False, linear_projection=False, bone_length_term=True, no_proj=False, viz_subject='video4.mp4', viz_action='custom', viz_camera=0, viz_video='video/video4.mp4', viz_skip=0, viz_output='video_output/output_video4.mp4', viz_export=None, viz_bitrate=3000, viz_no_ground_truth=False, viz_limit=-1, viz_downsample=1, viz_size=6)
# Loading dataset...
# Preparing data...
# Loading 2D detections...
# INFO: Receptive field: 243 frames
# INFO: Trainable parameter count: 16952371
# Loading checkpoint checkpoint/pretrained_h36m_detectron_coco.bin
# This model was trained for 80 epochs
# INFO: Testing on 424 frames
# Rendering...
# INFO: this action is unlabeled. Ground truth will not be rendered.
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video/video4.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:17.00, start: 3.040000, bitrate: 18665 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 2160x4096, 18663 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : L-SMASH Video Handler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, image2pipe, to 'pipe:':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: rawvideo (RGB[24] / 0x18424752), rgb24, 2160x4096, q=2-31, 5308416 kb/s, 25 fps, 25 tbn, 25 tbc (default)
#     Metadata:
#       handler_name    : L-SMASH Video Handler
#       encoder         : Lavc58.54.100 rawvideo
# frame=  424 fps= 20 q=-0.0 Lsize=10990080kB time=00:00:16.96 bitrate=5308416.0kbits/s speed=0.783x
# video:10990080kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# /userhome/cs/am203/COMP7404/VideoPose3D/common/visualization.py:198: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   fig.tight_layout()
# 423/424

# %%
from IPython.display import Video
output_video_filename = 'output_video3.mp4'
Video(output_dir+"/"+output_video_filename)
# Out:
# <video src="video_output/output_video3.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
