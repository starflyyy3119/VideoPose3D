# %%
# Check CUDA and Torch version (optional)
# !nvcc --version
import torch 
print("Torch:", torch.__version__)
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0
# Torch 1.10.0

# %%
# Override the installation with specific version
conda install pytorch==1.10.0 torchvision==0.11.0 torchaudio==0.10.0 cudatoolkit=11.3 -c pytorch -c conda-forge
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /userhome/cs/am203/anaconda3
#
#   added / updated specs:
#     - cudatoolkit=11.3
#     - pytorch==1.10.0
#     - torchaudio==0.10.0
#     - torchvision==0.11.0
#
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2022.4.26-~ --> conda-forge::ca-certificates-2022.6.15-ha878542_0
#   conda              pkgs/main::conda-4.13.0-py39h06a4308_0 --> conda-forge::conda-4.13.0-py39hf3d152e_1
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            pkgs/main::certifi-2022.6.15-py39h06a~ --> conda-forge::certifi-2022.6.15-py39hf3d152e_0
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# Install other necessary packages
# !pip install ffmpeg
# !pip install cdflib
# !conda update ffmpeg -y
# Out:
# WARNING: Ignoring invalid distribution -illow (/userhome/cs/am203/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/userhome/cs/am203/anaconda3/lib/python3.9/site-packages)
# ...
# WARNING: Ignoring invalid distribution -illow (/userhome/cs/am203/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/userhome/cs/am203/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/userhome/cs/am203/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/userhome/cs/am203/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/userhome/cs/am203/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/userhome/cs/am203/anaconda3/lib/python3.9/site-packages)
# ...
# WARNING: Ignoring invalid distribution -illow (/userhome/cs/am203/anaconda3/lib/python3.9/site-packages)
# ...

# %%
# install Detectron2 
# !python -m pip install detectron2 -f \
  https://dl.fbaipublicfiles.com/detectron2/wheels/cu113/torch1.10/index.html
# Out:
# WARNING: Ignoring invalid distribution -illow (/userhome/cs/am203/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/userhome/cs/am203/anaconda3/lib/python3.9/site-packages)
# Looking in links: https://dl.fbaipublicfiles.com/detectron2/wheels/cu113/torch1.10/index.html
# ...
#      |████████████████████████████████| 6.9 MB 645 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 130 kB 13.0 MB/s eta 0:00:01
# ...
# WARNING: Ignoring invalid distribution -illow (/userhome/cs/am203/anaconda3/lib/python3.9/site-packages)
# ...
#   Attempting uninstall: black
#     WARNING: Ignoring invalid distribution -illow (/userhome/cs/am203/anaconda3/lib/python3.9/site-packages)
#     Found existing installation: black 22.3.0
#     Uninstalling black-22.3.0:
#       Successfully uninstalled black-22.3.0
# WARNING: Ignoring invalid distribution -illow (/userhome/cs/am203/anaconda3/lib/python3.9/site-packages)
# ...

# %%
# Make this directory if not exist, we will clone the PJ file into here
cd /userhome/cs/am203/COMP7404
# Out:
# Cloning into 'VideoPose3D'...
# remote: Enumerating objects: 136, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 136 (delta 4), reused 12 (delta 4), pack-reused 123
# Receiving objects: 100% (136/136), 138.29 MiB | 14.68 MiB/s, done.
# Resolving deltas: 100% (45/45), done.
# Checking out files: 100% (46/46), done.

# %%
# !git clone https://github.com/starflyyy3119/VideoPose3D.git

# %%
cd /userhome/cs/am203/COMP7404/VideoPose3D
# Out:
# Namespace(dataset='h36m', keypoints='cpn_ft_h36m_dbb', subjects_train='S1,S5,S6,S7,S8', subjects_test='S9,S11', subjects_unlabeled='', actions='*', checkpoint='checkpoint', checkpoint_frequency=10, resume='', evaluate='pretrained_h36m_cpn.bin', render=False, by_subject=False, export_training_curves=False, stride=1, epochs=60, batch_size=1024, dropout=0.25, learning_rate=0.001, lr_decay=0.95, data_augmentation=True, test_time_augmentation=True, architecture='3,3,3,3,3', causal=False, channels=1024, subset=1, downsample=1, warmup=1, no_eval=False, dense=False, disable_optimizations=False, linear_projection=False, bone_length_term=True, no_proj=False, viz_subject=None, viz_action=None, viz_camera=0, viz_video=None, viz_skip=0, viz_output=None, viz_export=None, viz_bitrate=3000, viz_no_ground_truth=False, viz_limit=-1, viz_downsample=1, viz_size=5)
# Loading dataset...
# Traceback (most recent call last):
#   File "/userhome/cs/am203/COMP7404/VideoPose3D/run.py", line 41, in <module>
# ...

# %%
# !python run.py -k cpn_ft_h36m_dbb -arc 3,3,3,3,3 -c checkpoint --evaluate pretrained_h36m_cpn.bin

# %%
# !python inference/infer_video_d2.py \
    --cfg COCO-Keypoints/keypoint_rcnn_R_101_FPN_3x.yaml \
    --output-dir video_output \
    --image-ext mp4 \
    video
# Out:
# Processing video/cxk.mp4
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
# ...

# %%
cd /userhome/cs/am203/COMP7404/VideoPose3D/data
# Out:
# /userhome/cs/am203/COMP7404/VideoPose3D/data

# %%
# !python prepare_data_2d_custom.py -i /userhome/cs/am203/COMP7404/VideoPose3D/video_output -o cxk_am
# Out:
# Parsing 2D detections from /userhome/cs/am203/COMP7404/VideoPose3D/video_output
# Processing /userhome/cs/am203/COMP7404/VideoPose3D/video_output/cxk.mp4.npz
# 1022 total frames processed
# 0 frames were interpolated
# ----------
# Saving...
# Done.

# %%
cd /userhome/cs/am203/COMP7404/VideoPose3D
# Out:
# /userhome/cs/am203/COMP7404/VideoPose3D

# %%
# !python run.py -d custom -k cxk_am -arc 3,3,3,3,3 -c checkpoint --evaluate pretrained_h36m_detectron_coco.bin --render --viz-subject cxk.mp4 --viz-action custom --viz-camera 0 --viz-video /userhome/cs/am203/COMP7404/VideoPose3D/video/cxk.mp4 --viz-output video/output.mp4 --viz-size 6
# Out:
# Namespace(dataset='custom', keypoints='cxk_am', subjects_train='S1,S5,S6,S7,S8', subjects_test='S9,S11', subjects_unlabeled='', actions='*', checkpoint='checkpoint', checkpoint_frequency=10, resume='', evaluate='pretrained_h36m_detectron_coco.bin', render=True, by_subject=False, export_training_curves=False, stride=1, epochs=60, batch_size=1024, dropout=0.25, learning_rate=0.001, lr_decay=0.95, data_augmentation=True, test_time_augmentation=True, architecture='3,3,3,3,3', causal=False, channels=1024, subset=1, downsample=1, warmup=1, no_eval=False, dense=False, disable_optimizations=False, linear_projection=False, bone_length_term=True, no_proj=False, viz_subject='cxk.mp4', viz_action='custom', viz_camera=0, viz_video='/userhome/cs/am203/COMP7404/VideoPose3D/video/cxk.mp4', viz_skip=0, viz_output='output.mp4', viz_export=None, viz_bitrate=3000, viz_no_ground_truth=False, viz_limit=-1, viz_downsample=1, viz_size=6)
# Loading dataset...
# Preparing data...
# Loading 2D detections...
# ...
